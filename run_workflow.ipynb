# %% [markdown]
# # 股票筛选全流程自动化
#
# 这个 Notebook 包含 4 个步骤，用于自动执行完整的选股流程：
#
# 1. **Fetch Data**: 获取全市场日线数据
# 2. **Trend Bottom**: 运行 TD 九底分析
# 3. **Steady Uptrend**: 运行稳步上升 + 玄学指标分析
# 4. **Compare**: 对比两边结果，找出重合股票

# %%
pwd
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Park\\stocks-fliter'

# %%
import os

# 确保在项目根目录
project_root = r"c:\Users\Administrator\Desktop\Park\stocks-fliter"
if os.path.exists(project_root):
    os.chdir(project_root)
    print(f"✅ 已切换到工作目录: {os.getcwd()}")
else:
    print(f"⚠️ 警告: 目录不存在 {project_root}，请检查路径")
# Out:
# ✅ 已切换到工作目录: C:\Users\Administrator\Desktop\Park\stocks-fliter

# %% [markdown]
# ## 步骤 1: 获取全市场数据
#
# 这一步会调用 `get-data` 模块获取最新的日线数据。
# 如果数据量大，可能需要 10-20 分钟。

# %%
# 运行 get-data (使用 --all 获取全部股票，或者去掉 --all 使用默认随机测试)
# 建议: 如果是盘后分析，请务必加上 --all
# !python get-data/main.py

# %% [markdown]
# ## 步骤 2: TD 九底分析 (Trend Bottom)
#
# 分析下跌衰竭信号，识别可能的底部反转。

# %%
# !python check-trend-bottom/main.py --test
# Out:
# ============================================================
# ? TD九底分析系统
# ============================================================
#
# ? 第一步: TD分析
# ----------------------------------------
#   ? 开始分析 10 只股票...
# [数据] 分析数据基准日期: 2026-01-30
#
# TD分析: [------------------------------] 0/10 (0.0%) | 耗时:0.0s ETA:0.0s
# TD分析: [###---------------------------] 1/10 (10.0%) | 耗时:0.0s ETA:0.2s [OK:1 Fail:0]
# TD分析: [######------------------------] 2/10 (20.0%) | 耗时:0.0s ETA:0.1s [OK:2 Fail:0]
# TD分析: [#########---------------------] 3/10 (30.0%) | 耗时:0.1s ETA:0.1s [OK:3 Fail:0]
# TD分析: [############------------------] 4/10 (40.0%) | 耗时:0.1s ETA:0.1s [OK:4 Fail:0]
# TD分析: [###############---------------] 5/10 (50.0%) | 耗时:0.1s ETA:0.1s [OK:5 Fail:0]
# TD分析: [##################------------] 6/10 (60.0%) | 耗时:0.1s ETA:0.1s [OK:6 Fail:0]
# TD分析: [#####################---------] 7/10 (70.0%) | 耗时:0.1s ETA:0.1s [OK:7 Fail:0]
# TD分析: [########################------] 8/10 (80.0%) | 耗时:0.2s ETA:0.0s [OK:8 Fail:0]
# TD分析: [###########################---] 9/10 (90.0%) | 耗时:0.2s ETA:0.0s [OK:9 Fail:0]
# TD分析: [##############################] 10/10 (100.0%) | 耗时:0.2s ETA:0.0s [OK:10 Fail:0]
#
# [统计] 总计: 10 | 成功: 10 | 失败: 0
# [数据] 数据最新日期: 2026-01-30
#   ? 分析完成: 10 只股票
#   ? 数据最新日期: 2026-01-30
#   ? CSV: td_analysis_20260131_052234.csv
#
#   ? 底部统计:
#       无底部信号: 8
#       周9底: 1
#       日7底: 1
#
# ? 第二步: 筛选
# ----------------------------------------
#   ? 筛选完成: 2 只有底部信号的股票
#
# ? 第三步: 生成报告
# ----------------------------------------
#   ? Markdown: td_report_20260131_052234.md
#
# ? 错误: 'C:\\Users\\Administrator\\Desktop\\Park\\stocks-fliter\\check-trend-bottom\\output\\2026-01-30\\05-22-34\\summary_20260130_052234.html' does not start with ''
# Traceback (most recent call last):
#   File "check-trend-bottom/main.py", line 138, in main
#     end_date=args.end_date,
#   File "check-trend-bottom\pipeline.py", line 233, in run_pipeline
#     return pipeline.run()
#   File "check-trend-bottom\pipeline.py", line 177, in run
#     html_path = html_reporter.generate(df_filtered, title="TD九底分析报告")
#   File "check-trend-bottom\reporters\html_reporter.py", line 80, in generate
#     self._export_to_index_csv(df, "TD九底", date_str, summary_path)
#   File "check-trend-bottom\reporters\html_reporter.py", line 663, in _export_to_index_csv
#     relative_path = report_path.relative_to(project_root)
#   File "C:\ProgramData\Anaconda3\lib\pathlib.py", line 856, in relative_to
#     .format(str(self), str(formatted)))
# ValueError: 'C:\\Users\\Administrator\\Desktop\\Park\\stocks-fliter\\check-trend-bottom\\output\\2026-01-30\\05-22-34\\summary_20260130_052234.html' does not start with ''

# %% [markdown]
# ## 步骤 3: 稳步上升 + 玄学分析
#
# 分析稳步上升趋势，并应用玄学指标（6连阳等）。

# %%
# 运行 check-steady-uptrend
# 默认启用了 analyzers=1,3,4,x (包含玄学指标)
# !python check-steady-uptrend/main.py --test
# Out:
# [INFO] 输出目录: C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\output\2026-01-31\05-26-30
# [INFO] 开始完整分析流程...
#
# [1/4] 运行稳步上升分析...
# [稳步上升] 数据最新日期: 2026-01-30
#   [OK] 稳步上升结果: steady_uptrend_only_20260131_052630.csv (0 只)
#
# [2/4] 运行趋势分析...
#   [OK] 趋势分析详情: trend_rules_detail_20260131_052631.csv (10 只)
#   [OK] 趋势分析汇总: trend_rules_summary_20260131_052631.csv
#   [OK] 玄学候选: mystic_candidates_20260131_052631.csv (10 只)
# [趋势分析] 数据最新日期: 2026-01-30
#
# [3/4] 运行网格测试...
# [网格测试] 数据最新日期: 2026-01-30
#   [OK] 网格测试汇总: vol_contraction_grid_summary_20260131_052632.csv (54 组参数)
#   [OK] 网格测试报告: vol_contraction_grid_report_20260131_052632.md
#
# [4/4] 汇总玄学指标...
#   [OK] xuanxue_134_6: 0 只
#   [OK] xuanxue_134_61: 0 只
#   [OK] xuanxue_13_6: 0 只
#   [OK] xuanxue_13_61: 0 只
#   [OK] xuanxue_3_6: 0 只
#   [OK] xuanxue_3_61: 0 只
#   [OK] xuanxue_34_6: 0 只
#   [OK] xuanxue_34_61: 0 只
#   [OK] xuanxue_14_6: 0 只
#   [OK] xuanxue_14_61: 0 只
#   [OK] xuanxue_1_6: 0 只
#   [OK] xuanxue_1_61: 0 只
#   [OK] xuanxue_4_6: 0 只
#   [OK] xuanxue_4_61: 0 只
#   [OK] xuanxue_134_6t: 0 只
#   [OK] xuanxue_134_61t: 0 只
#   [OK] xuanxue_13_6t: 0 只
#   [OK] xuanxue_13_61t: 0 只
# [ERROR] 流程执行失败: 'DataFrame' object has no attribute 'to_markdown'
# 稳步上升分析:   0%|          | 0/10 [00:00<?, ?it/s]
# 稳步上升分析:  30%|███       | 3/10 [00:00<00:00, 29.74it/s]
# 稳步上升分析:  70%|███████   | 7/10 [00:00<00:00, 31.20it/s]
# 稳步上升分析: 100%|██████████| 10/10 [00:00<00:00, 32.84it/s]
#
# 趋势分析:   0%|          | 0/10 [00:00<?, ?it/s]
# 趋势分析:  30%|███       | 3/10 [00:00<00:00, 29.21it/s]
# 趋势分析:  60%|██████    | 6/10 [00:00<00:00, 27.94it/s]
# 趋势分析:  90%|█████████ | 9/10 [00:00<00:00, 24.85it/s]
# 趋势分析: 100%|██████████| 10/10 [00:00<00:00, 22.35it/s]
#
# 网格测试:   0%|          | 0/10 [00:00<?, ?it/s]
# 网格测试: 100%|██████████| 10/10 [00:00<00:00, 338.76it/s]
# Traceback (most recent call last):
#   File "C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\pipeline.py", line 93, in run_full
#     self._combine_results()
#   File "C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\pipeline.py", line 374, in _combine_results
#     self.result.combined = combiner.run()
#   File "C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\combiners\xuanxue_combiner.py", line 164, in run
#     original_count=original_count if strategy_name.endswith('t') else None,
#   File "C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\combiners\xuanxue_combiner.py", line 468, in _save_report
#     lines += self._generate_industry_stats(candidates)
#   File "C:\Users\Administrator\Desktop\Park\stocks-fliter\check-steady-uptrend\combiners\xuanxue_combiner.py", line 522, in _generate_industry_stats
#     board_counts.to_markdown(index=False),
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py", line 4376, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'DataFrame' object has no attribute 'to_markdown'

# %% [markdown]
# ## 步骤 4: 结果交叉对比
#
# 自动找出同时被上述两个策略选中的股票。

# %%
# 运行对比脚本
# !python compare_modules.py
